# %%
from random import uniform
import math

# %%
All_Lost = 0
BasicOptOfferPrice = 35
BasicOptOfferVol = 50
BasicStore = 80
InitAccount = 10000
InitQualification = 10
Max_Qualification = 100
Max_Demand = 30
MeanDPrice = 100
OptOfferAcceptDecision = 1
OptOfferBaseVolume = 40
RentRate = 200
Ret_Price = 100
ShopStore = 30
STOP_SELL = 0
TransferDecision = 1
TransferRate = 150
TransferVol = 30
VagesAndTaxes = 500
dt = 1
TIME = 0

# %%
def params_changing(text):
    if input(text).lower() == 'y':
        return True
    else:
        return False

# %%
timer = 100

Account = InitAccount
Qualification = InitQualification

BasicPriceRnd = BasicOptOfferVol * (uniform(.7, 1.3))
AddPriceByTime = BasicOptOfferPrice * 0.03 * TIME + BasicOptOfferPrice * 0.01 * TIME * uniform(0, 1)
OfferOnePrice = AddPriceByTime + BasicPriceRnd
RndOfferVolume = round(OptOfferBaseVolume * uniform(0.75, 1.25))
OfferFullPrice = OfferOnePrice * RndOfferVolume
OfferAcceptPossibility = 1 if Account >= OfferFullPrice else 0
SmallOptIncom = OfferAcceptPossibility * OptOfferAcceptDecision * RndOfferVolume

TransferActualVolue = min(BasicStore, TransferVol * TransferDecision) if Account >= TransferRate else 0
GoodsTransfer = math.floor(TransferActualVolue)
Lost = ShopStore + GoodsTransfer - 100 if ShopStore + GoodsTransfer > 100 else 0

QualSpending = round(Account * uniform(0.05, 0.2))
IncreaseQual = min(Max_Qualification-Qualification, (QualSpending/Account)*10)

Demand = round(Max_Demand * (1 - 1 / (1 + Qualification/Max_Qualification*10 + math.exp(-0.05 * (Ret_Price - MeanDPrice)))))
RND_Demand = round(Demand * uniform(0.7, 1.2))
SoldRet = (1 - STOP_SELL) * min(RND_Demand, ShopStore)
Selling = SoldRet
Income = Ret_Price * SoldRet

DailySpending = min(RentRate + VagesAndTaxes, Account)
TransSpend = TransferRate if TransferActualVolue > 0 else 0

print("-----------INITIAL DATA-----------")
print("-----------LEVEL VALUES-----------")
print(f"Account = {Account}")
print(f"BasicStore = {BasicStore}")
print(f"ShopStore = {ShopStore}")
print(f"Qualification = {Qualification}")
print("---------CHANGEABLE VALUES--------")
print(f"TransferVolume = {TransferVol}")
print(f"Ret_Price = {Ret_Price}")
print(f"STOP_SELL = {bool(STOP_SELL)}")
print(f"OptOfferAcceptDecision = {bool(OptOfferAcceptDecision)}")
print(f"TransferDecision = {bool(TransferDecision)}")
print("---------AUXILIARY VALUES---------")
print(f"RndOfferVolume = {RndOfferVolume}")
print(f"OfferFullPrice = {OfferFullPrice}")
print(f"OfferOnePrice = {OfferOnePrice}")
print(f"RND_Demand = {RND_Demand}")
print()
account_data = [Account]
qualification_data = [Qualification]
demand_data = [Demand]

flag = params_changing("Вы хотите внести изменения в параметры? Y/N")

for TIME in range(1, timer + 1):
    if flag:
        change_params = params_changing(f'Do you want to change parameters on {TIME} itereration?')
        if change_params:
            TransferVol = float(input(f"Write TransferVolume"))
            Ret_Price = float(input(f"Write Ret_Price"))
            STOP_SELL = 1 if input(f"Write STOP_SELL (y/n)").lower() == 'y' else 0
            OptOfferAcceptDecision = 1 if input(f"Write OptOfferAcceptDecision (y/n)").lower() == 'y' else 0
            TransferDecision = 1 if input(f"Write TransferDecision (y/n)").lower() == 'y' else 0
    Account += dt * (Income - DailySpending - TransSpend - QualSpending)
    BasicStore += dt * (SmallOptIncom - GoodsTransfer)
    ShopStore += dt * (GoodsTransfer - Selling - Lost)
    Qualification += dt * IncreaseQual
    All_Lost += dt * Lost

    BasicPriceRnd = BasicOptOfferVol * (uniform(.7, 1.3))
    AddPriceByTime = BasicOptOfferPrice * 0.03 * TIME + BasicOptOfferPrice * 0.01 * TIME * uniform(0, 1)
    OfferOnePrice = AddPriceByTime + BasicPriceRnd
    RndOfferVolume = round(OptOfferBaseVolume * uniform(0.75, 1.25))
    OfferFullPrice = OfferOnePrice * RndOfferVolume
    OfferAcceptPossibility = 1 if Account >= OfferFullPrice else 0
    SmallOptIncom = OfferAcceptPossibility * OptOfferAcceptDecision * RndOfferVolume

    TransferActualVolue = min(BasicStore, TransferVol * TransferDecision) if Account >= TransferRate else 0
    GoodsTransfer = math.floor(TransferActualVolue)
    Lost = ShopStore + GoodsTransfer - 100 if ShopStore + GoodsTransfer > 100 else 0
#Квалификация
    QualSpending = round(Account * uniform(0.05, 0.2))
    IncreaseQual = min(Max_Qualification-Qualification, (QualSpending/Account)*10)

    
    
    Demand = round(Max_Demand * (1 - 1 / (1 + Qualification/Max_Qualification*10 + math.exp(-0.05 * (Ret_Price - MeanDPrice)))))
    RND_Demand = round(Demand * uniform(0.7, 1.2))
    SoldRet = (1 - STOP_SELL) * min(RND_Demand, ShopStore)
    Selling = SoldRet
    Income = Ret_Price * SoldRet

    DailySpending = min(RentRate+VagesAndTaxes, Account)
    TransSpend = TransferRate if TransferActualVolue > 0 else 0

    account_data.append(Account)
    qualification_data.append(Qualification)
    demand_data.append(Demand)

    print(f"-------DATA ON STEP {TIME}-------")
    print("-----------LEVEL VALUES-----------")
    print(f"Account = {Account}")
    print(f"BasicStore = {BasicStore}")
    print(f"ShopStore = {ShopStore}")
    print(f"Qualification = {Qualification}")
    print("---------CHANGEABLE VALUES--------")
    print(f"TransferVolume = {TransferVol}")
    print(f"Ret_Price = {Ret_Price}")
    print(f"STOP_SELL = {bool(STOP_SELL)}")
    print(f"OptOfferAcceptDecision = {bool(OptOfferAcceptDecision)}")
    print(f"TransferDecision = {bool(TransferDecision)}")
    print("---------AUXILIARY VALUES---------")
    print(f"RndOfferVolume = {RndOfferVolume}")
    print(f"OfferFullPrice = {OfferFullPrice}")
    print(f"OfferOnePrice = {OfferOnePrice}")
    print(f"RND_Demand = {RND_Demand}")
    print()
# Out:
# -----------INITIAL DATA-----------
# -----------LEVEL VALUES-----------
# Account = 10000
# BasicStore = 1139
# ShopStore = 71
# Qualification = 10
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 34
# OfferFullPrice = 6383.623726434786
# OfferOnePrice = 187.7536390127878
# RND_Demand = 22
#
# Вы хотите внести изменения в параметры? Y/N
# -------DATA ON STEP 1-------
# -----------LEVEL VALUES-----------
# Account = 10145
# BasicStore = 1143
# ShopStore = 78
# Qualification = 11.205
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 2119.256426679422
# OfferOnePrice = 43.2501311567229
# RND_Demand = 18
#
# -------DATA ON STEP 2-------
# -----------LEVEL VALUES-----------
# Account = 10251
# BasicStore = 1162
# ShopStore = 82
# Qualification = 12.036936914736323
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 2063.084536046554
# OfferOnePrice = 52.89960348837318
# RND_Demand = 18
#
# -------DATA ON STEP 3-------
# -----------LEVEL VALUES-----------
# Account = 9872
# BasicStore = 1171
# ShopStore = 82
# Qualification = 13.33339579679661
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 2105.82494731181
# OfferOnePrice = 56.914187765184046
# RND_Demand = 21
#
# -------DATA ON STEP 4-------
# -----------LEVEL VALUES-----------
# Account = 9996
# BasicStore = 1178
# ShopStore = 79
# Qualification = 14.473995472647502
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 2440.234893446158
# OfferOnePrice = 53.04858464013387
# RND_Demand = 15
#
# -------DATA ON STEP 5-------
# -----------LEVEL VALUES-----------
# Account = 9740
# BasicStore = 1194
# ShopStore = 85
# Qualification = 15.38035801766551
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 1570.511987535907
# OfferOnePrice = 50.661677017287325
# RND_Demand = 18
#
# -------DATA ON STEP 6-------
# -----------LEVEL VALUES-----------
# Account = 9353
# BasicStore = 1195
# ShopStore = 82
# Qualification = 16.753047956063867
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 1783.974351247015
# OfferOnePrice = 54.05982882566712
# RND_Demand = 24
#
# -------DATA ON STEP 7-------
# -----------LEVEL VALUES-----------
# Account = 9417
# BasicStore = 1198
# ShopStore = 76
# Qualification = 18.34184299508878
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 2181.9390066549763
# OfferOnePrice = 45.45706263864534
# RND_Demand = 17
#
# -------DATA ON STEP 8-------
# -----------LEVEL VALUES-----------
# Account = 9011
# BasicStore = 1216
# ShopStore = 83
# Qualification = 19.67560109214729
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 2844.0355755430846
# OfferOnePrice = 59.2507411571476
# RND_Demand = 22
#
# -------DATA ON STEP 9-------
# -----------LEVEL VALUES-----------
# Account = 9123
# BasicStore = 1234
# ShopStore = 78
# Qualification = 21.049477465468787
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 2192.0730389672485
# OfferOnePrice = 52.19221521350592
# RND_Demand = 20
#
# -------DATA ON STEP 10-------
# -----------LEVEL VALUES-----------
# Account = 9598
# BasicStore = 1246
# ShopStore = 80
# Qualification = 21.78936566014159
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 3225.9631353274917
# OfferOnePrice = 68.63751351760621
# RND_Demand = 16
#
# -------DATA ON STEP 11-------
# -----------LEVEL VALUES-----------
# Account = 9518
# BasicStore = 1263
# ShopStore = 84
# Qualification = 22.65412915253584
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 3116.9671730861364
# OfferOnePrice = 76.02358958746674
# RND_Demand = 17
#
# -------DATA ON STEP 12-------
# -----------LEVEL VALUES-----------
# Account = 8714
# BasicStore = 1274
# ShopStore = 83
# Qualification = 24.391889186156348
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 2674.5291206463116
# OfferOnePrice = 56.90487490736833
# RND_Demand = 17
#
# -------DATA ON STEP 13-------
# -----------LEVEL VALUES-----------
# Account = 8927
# BasicStore = 1291
# ShopStore = 83
# Qualification = 25.12289676017517
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 2804.686028097224
# OfferOnePrice = 65.2252564673773
# RND_Demand = 21
#
# -------DATA ON STEP 14-------
# -----------LEVEL VALUES-----------
# Account = 8478
# BasicStore = 1304
# ShopStore = 79
# Qualification = 27.026111726009155
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 3448.4565842717193
# OfferOnePrice = 70.37666498513713
# RND_Demand = 19
#
# -------DATA ON STEP 15-------
# -----------LEVEL VALUES-----------
# Account = 9090
# BasicStore = 1323
# ShopStore = 81
# Qualification = 27.542743006971648
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 2399.2871630550208
# OfferOnePrice = 64.84559900148705
# RND_Demand = 28
#
# -------DATA ON STEP 16-------
# -----------LEVEL VALUES-----------
# Account = 10377
# BasicStore = 1330
# ShopStore = 72
# Qualification = 28.272115944265376
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 3915.2731089227805
# OfferOnePrice = 79.90353283515879
# RND_Demand = 18
#
# -------DATA ON STEP 17-------
# -----------LEVEL VALUES-----------
# Account = 9465
# BasicStore = 1349
# ShopStore = 82
# Qualification = 30.066468840092686
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 2559.801555072502
# OfferOnePrice = 73.13718728778578
# RND_Demand = 27
#
# -------DATA ON STEP 18-------
# -----------LEVEL VALUES-----------
# Account = 10116
# BasicStore = 1354
# ShopStore = 73
# Qualification = 31.333241159162945
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 1880.95225486867
# OfferOnePrice = 62.69840849562233
# RND_Demand = 24
#
# -------DATA ON STEP 19-------
# -----------LEVEL VALUES-----------
# Account = 11009
# BasicStore = 1354
# ShopStore = 76
# Qualification = 31.982707351333765
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 3127.7562507097764
# OfferOnePrice = 65.16158855645368
# RND_Demand = 25
#
# -------DATA ON STEP 20-------
# -----------LEVEL VALUES-----------
# Account = 10498
# BasicStore = 1372
# ShopStore = 75
# Qualification = 33.94564676454114
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 50
# OfferFullPrice = 3461.62106526895
# OfferOnePrice = 69.232421305379
# RND_Demand = 18
#
# -------DATA ON STEP 21-------
# -----------LEVEL VALUES-----------
# Account = 10556
# BasicStore = 1392
# ShopStore = 82
# Qualification = 34.7953324189515
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 2341.4623001381287
# OfferOnePrice = 65.04061944828135
# RND_Demand = 27
#
# -------DATA ON STEP 22-------
# -----------LEVEL VALUES-----------
# Account = 11005
# BasicStore = 1398
# ShopStore = 73
# Qualification = 36.12253969443464
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 3928.828040708393
# OfferOnePrice = 89.2915463797362
# RND_Demand = 23
#
# -------DATA ON STEP 23-------
# -----------LEVEL VALUES-----------
# Account = 10804
# BasicStore = 1412
# ShopStore = 77
# Qualification = 37.62276686390307
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 4143.038589883924
# OfferOnePrice = 90.06605630182443
# RND_Demand = 23
#
# -------DATA ON STEP 24-------
# -----------LEVEL VALUES-----------
# Account = 10938
# BasicStore = 1428
# ShopStore = 77
# Qualification = 38.840834246354014
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 2443.3975703085566
# OfferOnePrice = 66.03777217050153
# RND_Demand = 18
#
# -------DATA ON STEP 25-------
# -----------LEVEL VALUES-----------
# Account = 9837
# BasicStore = 1435
# ShopStore = 82
# Qualification = 40.715948526844045
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 2958.4376598886934
# OfferOnePrice = 84.5267902825341
# RND_Demand = 29
#
# -------DATA ON STEP 26-------
# -----------LEVEL VALUES-----------
# Account = 10442
# BasicStore = 1440
# ShopStore = 71
# Qualification = 42.18489231051793
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 2854.64502436415
# OfferOnePrice = 92.08532336658547
# RND_Demand = 22
#
# -------DATA ON STEP 27-------
# -----------LEVEL VALUES-----------
# Account = 10916
# BasicStore = 1441
# ShopStore = 78
# Qualification = 43.0238120576928
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 3366.6714733625
# OfferOnePrice = 82.11393837469512
# RND_Demand = 25
#
# -------DATA ON STEP 28-------
# -----------LEVEL VALUES-----------
# Account = 10911
# BasicStore = 1452
# ShopStore = 75
# Qualification = 44.53993517971552
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 2690.7522700259155
# OfferOnePrice = 76.87863628645474
# RND_Demand = 23
#
# -------DATA ON STEP 29-------
# -----------LEVEL VALUES-----------
# Account = 10409
# BasicStore = 1457
# ShopStore = 77
# Qualification = 46.328955434504266
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 2982.502745901027
# OfferOnePrice = 78.4869143658165
# RND_Demand = 26
#
# -------DATA ON STEP 30-------
# -----------LEVEL VALUES-----------
# Account = 11125
# BasicStore = 1465
# ShopStore = 74
# Qualification = 47.322326555649425
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 4138.026786220607
# OfferOnePrice = 96.23318107489786
# RND_Demand = 23
#
# -------DATA ON STEP 31-------
# -----------LEVEL VALUES-----------
# Account = 10620
# BasicStore = 1478
# ShopStore = 77
# Qualification = 49.07962992643594
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 2645.7828949899304
# OfferOnePrice = 85.34783532225582
# RND_Demand = 21
#
# -------DATA ON STEP 32-------
# -----------LEVEL VALUES-----------
# Account = 10568
# BasicStore = 1479
# ShopStore = 79
# Qualification = 50.30561862700091
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 4561.865865627481
# OfferOnePrice = 93.09930338015268
# RND_Demand = 21
#
# -------DATA ON STEP 33-------
# -----------LEVEL VALUES-----------
# Account = 11014
# BasicStore = 1498
# ShopStore = 79
# Qualification = 51.06640590936276
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 2803.666488218409
# OfferOnePrice = 80.10475680624026
# RND_Demand = 24
#
# -------DATA ON STEP 34-------
# -----------LEVEL VALUES-----------
# Account = 11168
# BasicStore = 1503
# ShopStore = 76
# Qualification = 52.33388366494656
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 4034.770066945798
# OfferOnePrice = 109.04783964718374
# RND_Demand = 20
#
# -------DATA ON STEP 35-------
# -----------LEVEL VALUES-----------
# Account = 11228
# BasicStore = 1510
# ShopStore = 80
# Qualification = 53.309886530276074
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 4638.960589672875
# OfferOnePrice = 94.6726650953648
# RND_Demand = 27
#
# -------DATA ON STEP 36-------
# -----------LEVEL VALUES-----------
# Account = 11790
# BasicStore = 1529
# ShopStore = 73
# Qualification = 54.457018699852135
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 3192.262997217716
# OfferOnePrice = 88.67397214493656
# RND_Demand = 30
#
# -------DATA ON STEP 37-------
# -----------LEVEL VALUES-----------
# Account = 13250
# BasicStore = 1535
# ShopStore = 70
# Qualification = 55.04226043013203
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 3588.3821134623613
# OfferOnePrice = 89.70955283655903
# RND_Demand = 27
#
# -------DATA ON STEP 38-------
# -----------LEVEL VALUES-----------
# Account = 13462
# BasicStore = 1545
# ShopStore = 73
# Qualification = 56.27848684522637
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 3519.669806870804
# OfferOnePrice = 100.56199448202298
# RND_Demand = 29
#
# -------DATA ON STEP 39-------
# -----------LEVEL VALUES-----------
# Account = 13636
# BasicStore = 1550
# ShopStore = 71
# Qualification = 57.672039066293074
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 2916.674642813619
# OfferOnePrice = 94.08627880043932
# RND_Demand = 28
#
# -------DATA ON STEP 40-------
# -----------LEVEL VALUES-----------
# Account = 14553
# BasicStore = 1551
# ShopStore = 72
# Qualification = 58.429592601054004
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 4400.755966312797
# OfferOnePrice = 89.81134625128156
# RND_Demand = 20
#
# -------DATA ON STEP 41-------
# -----------LEVEL VALUES-----------
# Account = 14586
# BasicStore = 1570
# ShopStore = 80
# Qualification = 59.19713194002191
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 4139.880263261812
# OfferOnePrice = 94.08818780140481
# RND_Demand = 20
#
# -------DATA ON STEP 42-------
# -----------LEVEL VALUES-----------
# Account = 14055
# BasicStore = 1584
# ShopStore = 80
# Qualification = 60.349606916026296
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 4530.695439093175
# OfferOnePrice = 113.26738597732938
# RND_Demand = 25
#
# -------DATA ON STEP 43-------
# -----------LEVEL VALUES-----------
# Account = 13595
# BasicStore = 1594
# ShopStore = 75
# Qualification = 61.850852024528606
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 3645.0552637894903
# OfferOnePrice = 117.5824278641771
# RND_Demand = 24
#
# -------DATA ON STEP 44-------
# -----------LEVEL VALUES-----------
# Account = 12622
# BasicStore = 1595
# ShopStore = 76
# Qualification = 63.706681373553984
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 5142.500013879522
# OfferOnePrice = 109.41489391233026
# RND_Demand = 26
#
# -------DATA ON STEP 45-------
# -----------LEVEL VALUES-----------
# Account = 13223
# BasicStore = 1612
# ShopStore = 74
# Qualification = 64.61699669600685
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 3581.9788789071686
# OfferOnePrice = 96.81023997046401
# RND_Demand = 23
#
# -------DATA ON STEP 46-------
# -----------LEVEL VALUES-----------
# Account = 13631
# BasicStore = 1619
# ShopStore = 77
# Qualification = 65.40501756872862
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 4985.847161454613
# OfferOnePrice = 106.08185449903434
# RND_Demand = 23
#
# -------DATA ON STEP 47-------
# -----------LEVEL VALUES-----------
# Account = 14291
# BasicStore = 1636
# ShopStore = 77
# Qualification = 65.98457886283764
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 50
# OfferFullPrice = 4329.927982141919
# OfferOnePrice = 86.59855964283837
# RND_Demand = 25
#
# -------DATA ON STEP 48-------
# -----------LEVEL VALUES-----------
# Account = 13843
# BasicStore = 1656
# ShopStore = 75
# Qualification = 67.45263568181461
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 4124.487818568201
# OfferOnePrice = 98.20209091829051
# RND_Demand = 23
#
# -------DATA ON STEP 49-------
# -----------LEVEL VALUES-----------
# Account = 14065
# BasicStore = 1668
# ShopStore = 77
# Qualification = 68.33972663030843
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 4177.559726438952
# OfferOnePrice = 107.11691606253723
# RND_Demand = 28
#
# -------DATA ON STEP 50-------
# -----------LEVEL VALUES-----------
# Account = 14263
# BasicStore = 1677
# ShopStore = 72
# Qualification = 69.58537184893623
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 32
# OfferFullPrice = 3830.938285971073
# OfferOnePrice = 119.71682143659604
# RND_Demand = 27
#
# -------DATA ON STEP 51-------
# -----------LEVEL VALUES-----------
# Account = 13913
# BasicStore = 1679
# ShopStore = 73
# Qualification = 71.1278243484104
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 4805.10169537971
# OfferOnePrice = 120.12754238449274
# RND_Demand = 26
#
# -------DATA ON STEP 52-------
# -----------LEVEL VALUES-----------
# Account = 13117
# BasicStore = 1689
# ShopStore = 74
# Qualification = 72.95776756698295
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 3489.604292603511
# OfferOnePrice = 105.74558462434882
# RND_Demand = 19
#
# -------DATA ON STEP 53-------
# -----------LEVEL VALUES-----------
# Account = 12538
# BasicStore = 1692
# ShopStore = 81
# Qualification = 74.19966739163797
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 34
# OfferFullPrice = 3413.518694109047
# OfferOnePrice = 100.39760865026608
# RND_Demand = 27
#
# -------DATA ON STEP 54-------
# -----------LEVEL VALUES-----------
# Account = 12750
# BasicStore = 1696
# ShopStore = 73
# Qualification = 75.5060958491272
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 5108.322318297914
# OfferOnePrice = 121.62672186423603
# RND_Demand = 21
#
# -------DATA ON STEP 55-------
# -----------LEVEL VALUES-----------
# Account = 11537
# BasicStore = 1708
# ShopStore = 79
# Qualification = 77.43786055500956
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 4482.691214704426
# OfferOnePrice = 112.06728036761064
# RND_Demand = 21
#
# -------DATA ON STEP 56-------
# -----------LEVEL VALUES-----------
# Account = 12123
# BasicStore = 1718
# ShopStore = 79
# Qualification = 78.01340012335488
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 3455.2067893128574
# OfferOnePrice = 111.45828352622121
# RND_Demand = 22
#
# -------DATA ON STEP 57-------
# -----------LEVEL VALUES-----------
# Account = 11175
# BasicStore = 1719
# ShopStore = 78
# Qualification = 79.90897052672038
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 6263.901126490314
# OfferOnePrice = 133.2744920529854
# RND_Demand = 25
#
# -------DATA ON STEP 58-------
# -----------LEVEL VALUES-----------
# Account = 10967
# BasicStore = 1736
# ShopStore = 75
# Qualification = 81.57161034774947
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 5127.141457701265
# OfferOnePrice = 125.0522306756406
# RND_Demand = 27
#
# -------DATA ON STEP 59-------
# -----------LEVEL VALUES-----------
# Account = 11699
# BasicStore = 1747
# ShopStore = 73
# Qualification = 82.59103224981932
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 5669.267732558547
# OfferOnePrice = 141.7316933139637
# RND_Demand = 27
#
# -------DATA ON STEP 60-------
# -----------LEVEL VALUES-----------
# Account = 12523
# BasicStore = 1757
# ShopStore = 73
# Qualification = 83.46803028383933
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 5327.4333695289915
# OfferOnePrice = 118.38740821175537
# RND_Demand = 23
#
# -------DATA ON STEP 61-------
# -----------LEVEL VALUES-----------
# Account = 11488
# BasicStore = 1772
# ShopStore = 77
# Qualification = 85.45237908205061
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 4586.876093826558
# OfferOnePrice = 127.41322482851548
# RND_Demand = 26
#
# -------DATA ON STEP 62-------
# -----------LEVEL VALUES-----------
# Account = 11563
# BasicStore = 1778
# ShopStore = 74
# Qualification = 86.91042225753807
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 5110.823927700799
# OfferOnePrice = 134.49536651844207
# RND_Demand = 26
#
# -------DATA ON STEP 63-------
# -----------LEVEL VALUES-----------
# Account = 11792
# BasicStore = 1786
# ShopStore = 74
# Qualification = 88.22582483472392
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 5387.306020342901
# OfferOnePrice = 122.4387731896114
# RND_Demand = 26
#
# -------DATA ON STEP 64-------
# -----------LEVEL VALUES-----------
# Account = 12662
# BasicStore = 1800
# ShopStore = 74
# Qualification = 88.97209349144035
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 50
# OfferFullPrice = 7367.438144581391
# OfferOnePrice = 147.3487628916278
# RND_Demand = 28
#
# -------DATA ON STEP 65-------
# -----------LEVEL VALUES-----------
# Account = 12088
# BasicStore = 1820
# ShopStore = 72
# Qualification = 90.96545946837922
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 5023.058784885978
# OfferOnePrice = 114.16042692922676
# RND_Demand = 27
#
# -------DATA ON STEP 66-------
# -----------LEVEL VALUES-----------
# Account = 11777
# BasicStore = 1834
# ShopStore = 73
# Qualification = 92.75318283039114
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 5586.3584748316
# OfferOnePrice = 133.0085351150381
# RND_Demand = 22
#
# -------DATA ON STEP 67-------
# -----------LEVEL VALUES-----------
# Account = 11891
# BasicStore = 1846
# ShopStore = 78
# Qualification = 93.80268609947495
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 5457.905729927898
# OfferOnePrice = 139.946300767382
# RND_Demand = 32
#
# -------DATA ON STEP 68-------
# -----------LEVEL VALUES-----------
# Account = 12469
# BasicStore = 1855
# ShopStore = 68
# Qualification = 95.29288877376644
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 5680.777448501499
# OfferOnePrice = 126.23949885558886
# RND_Demand = 30
#
# -------DATA ON STEP 69-------
# -----------LEVEL VALUES-----------
# Account = 13388
# BasicStore = 1870
# ShopStore = 68
# Qualification = 96.28013714973885
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 3910.6343926005884
# OfferOnePrice = 126.14949653550285
# RND_Demand = 19
#
# -------DATA ON STEP 70-------
# -----------LEVEL VALUES-----------
# Account = 13163
# BasicStore = 1871
# ShopStore = 79
# Qualification = 97.23248253366475
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 5616.417826567234
# OfferOnePrice = 124.80928503482744
# RND_Demand = 19
#
# -------DATA ON STEP 71-------
# -----------LEVEL VALUES-----------
# Account = 11998
# BasicStore = 1886
# ShopStore = 81
# Qualification = 98.91522962779223
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7281.079999243855
# OfferOnePrice = 151.68916665091365
# RND_Demand = 29
#
# -------DATA ON STEP 72-------
# -----------LEVEL VALUES-----------
# Account = 12919
# BasicStore = 1904
# ShopStore = 71
# Qualification = 99.85621979281973
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 5049.587719254479
# OfferOnePrice = 162.88992642756386
# RND_Demand = 27
#
# -------DATA ON STEP 73-------
# -----------LEVEL VALUES-----------
# Account = 12218
# BasicStore = 1905
# ShopStore = 73
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 5871.273695907826
# OfferOnePrice = 130.47274879795168
# RND_Demand = 23
#
# -------DATA ON STEP 74-------
# -----------LEVEL VALUES-----------
# Account = 12426
# BasicStore = 1920
# ShopStore = 77
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 34
# OfferFullPrice = 5365.079068964011
# OfferOnePrice = 157.79644320482385
# RND_Demand = 26
#
# -------DATA ON STEP 75-------
# -----------LEVEL VALUES-----------
# Account = 11914
# BasicStore = 1924
# ShopStore = 74
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 4901.561030981329
# OfferOnePrice = 136.1544730828147
# RND_Demand = 24
#
# -------DATA ON STEP 76-------
# -----------LEVEL VALUES-----------
# Account = 11180
# BasicStore = 1930
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 6628.864869082502
# OfferOnePrice = 157.83011593053575
# RND_Demand = 25
#
# -------DATA ON STEP 77-------
# -----------LEVEL VALUES-----------
# Account = 12057
# BasicStore = 1942
# ShopStore = 75
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 4112.172632099015
# OfferOnePrice = 137.07242106996716
# RND_Demand = 25
#
# -------DATA ON STEP 78-------
# -----------LEVEL VALUES-----------
# Account = 11667
# BasicStore = 1942
# ShopStore = 75
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 4706.322851476424
# OfferOnePrice = 156.87742838254746
# RND_Demand = 24
#
# -------DATA ON STEP 79-------
# -----------LEVEL VALUES-----------
# Account = 11559
# BasicStore = 1942
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 4905.957470543059
# OfferOnePrice = 132.5934451498124
# RND_Demand = 20
#
# -------DATA ON STEP 80-------
# -----------LEVEL VALUES-----------
# Account = 10659
# BasicStore = 1949
# ShopStore = 80
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 32
# OfferFullPrice = 5407.246504179709
# OfferOnePrice = 168.9764532556159
# RND_Demand = 26
#
# -------DATA ON STEP 81-------
# -----------LEVEL VALUES-----------
# Account = 10768
# BasicStore = 1951
# ShopStore = 74
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 7348.2708715465105
# OfferOnePrice = 159.74501894666327
# RND_Demand = 32
#
# -------DATA ON STEP 82-------
# -----------LEVEL VALUES-----------
# Account = 12145
# BasicStore = 1967
# ShopStore = 68
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 4008.031089327649
# OfferOnePrice = 133.60103631092164
# RND_Demand = 26
#
# -------DATA ON STEP 83-------
# -----------LEVEL VALUES-----------
# Account = 12203
# BasicStore = 1967
# ShopStore = 72
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7742.038841894551
# OfferOnePrice = 161.29247587280315
# RND_Demand = 24
#
# -------DATA ON STEP 84-------
# -----------LEVEL VALUES-----------
# Account = 12727
# BasicStore = 1985
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 6596.881442006956
# OfferOnePrice = 157.06860576207038
# RND_Demand = 27
#
# -------DATA ON STEP 85-------
# -----------LEVEL VALUES-----------
# Account = 12662
# BasicStore = 1997
# ShopStore = 73
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 5434.363084834179
# OfferOnePrice = 150.95453013428275
# RND_Demand = 29
#
# -------DATA ON STEP 86-------
# -----------LEVEL VALUES-----------
# Account = 13759
# BasicStore = 2003
# ShopStore = 71
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 6450.8019866797285
# OfferOnePrice = 146.60913606090293
# RND_Demand = 29
#
# -------DATA ON STEP 87-------
# -----------LEVEL VALUES-----------
# Account = 13512
# BasicStore = 2017
# ShopStore = 71
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 6055.205775395126
# OfferOnePrice = 134.5601283421139
# RND_Demand = 24
#
# -------DATA ON STEP 88-------
# -----------LEVEL VALUES-----------
# Account = 13982
# BasicStore = 2032
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 5659.900217798911
# OfferOnePrice = 141.49750544497277
# RND_Demand = 33
#
# -------DATA ON STEP 89-------
# -----------LEVEL VALUES-----------
# Account = 15606
# BasicStore = 2042
# ShopStore = 67
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 6852.682312920422
# OfferOnePrice = 152.28182917600938
# RND_Demand = 22
#
# -------DATA ON STEP 90-------
# -----------LEVEL VALUES-----------
# Account = 14170
# BasicStore = 2057
# ShopStore = 75
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 5647.636490709597
# OfferOnePrice = 161.36104259170276
# RND_Demand = 33
#
# -------DATA ON STEP 91-------
# -----------LEVEL VALUES-----------
# Account = 14299
# BasicStore = 2062
# ShopStore = 67
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 32
# OfferFullPrice = 5392.329108406941
# OfferOnePrice = 168.5102846377169
# RND_Demand = 29
#
# -------DATA ON STEP 92-------
# -----------LEVEL VALUES-----------
# Account = 14567
# BasicStore = 2064
# ShopStore = 68
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7889.126684819705
# OfferOnePrice = 164.35680593374386
# RND_Demand = 30
#
# -------DATA ON STEP 93-------
# -----------LEVEL VALUES-----------
# Account = 15513
# BasicStore = 2082
# ShopStore = 68
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 7098.569511451466
# OfferOnePrice = 161.3311252602606
# RND_Demand = 21
#
# -------DATA ON STEP 94-------
# -----------LEVEL VALUES-----------
# Account = 14543
# BasicStore = 2096
# ShopStore = 77
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 4850.475377147508
# OfferOnePrice = 156.4669476499196
# RND_Demand = 23
#
# -------DATA ON STEP 95-------
# -----------LEVEL VALUES-----------
# Account = 14363
# BasicStore = 2097
# ShopStore = 77
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 5772.640862397259
# OfferOnePrice = 160.35113506659053
# RND_Demand = 27
#
# -------DATA ON STEP 96-------
# -----------LEVEL VALUES-----------
# Account = 15291
# BasicStore = 2103
# ShopStore = 73
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 8633.747137322098
# OfferOnePrice = 179.8697320275437
# RND_Demand = 30
#
# -------DATA ON STEP 97-------
# -----------LEVEL VALUES-----------
# Account = 16529
# BasicStore = 2121
# ShopStore = 70
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 7139.324470469707
# OfferOnePrice = 192.9547154181002
# RND_Demand = 28
#
# -------DATA ON STEP 98-------
# -----------LEVEL VALUES-----------
# Account = 16008
# BasicStore = 2128
# ShopStore = 72
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 5350.642107850945
# OfferOnePrice = 162.1406699348771
# RND_Demand = 24
#
# -------DATA ON STEP 99-------
# -----------LEVEL VALUES-----------
# Account = 14649
# BasicStore = 2131
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 6506.726945342734
# OfferOnePrice = 151.31923128704034
# RND_Demand = 20
#
# -------DATA ON STEP 100-------
# -----------LEVEL VALUES-----------
# Account = 14602
# BasicStore = 2144
# ShopStore = 80
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 4907.263147176704
# OfferOnePrice = 163.57543823922344
# RND_Demand = 32

# %%
import matplotlib.pyplot as plt

# Создание первого графика для состояния счета и состояния налогов
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(account_data, label='Состояние счета', color='blue')
plt.title('Состояние счета')
plt.legend()
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(qualification_data, label='Уровень квалификации', color='red')
plt.plot(demand_data, label='Уровень спроса', color='green')
plt.title('Уровень квалификации')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
